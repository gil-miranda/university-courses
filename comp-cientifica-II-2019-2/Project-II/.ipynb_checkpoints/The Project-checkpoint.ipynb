# %% [markdown]
# # N-Body Problem and Symplectic Integrators
# > Author: Gil Miranda Neto<br>
# > Contact: gilsmneto@gmail.com<br>
# > Repo: [@mirandagil](https://github.com/mirandagil/university-courses/analise-numerica-edo-2019-1/project)<br>
#
# `last update: 30/05/2019`
#
# ---

# %%
import time

## --- Body class
from local_body import *

## --- Functions to simulate and plot
import local_functions as sim

# %% [markdown]
# ### Initializing the celestial bodies
# #### Setting Initial Values

# %%
sun = Body('Sun', 'yellow')
sun.mass = 1.98855e30
sun.size = 20

earth = Body('Earth', 'darkblue')
earth.mass = 5.9742e24
earth.p_x0 = 152.1e9
earth.v_y0 = 29.783e3
earth.size = 1

venus = Body('Venus', 'salmon')
venus.mass = 4.8685e24
venus.p_x0 = 108.9e9
venus.v_y0 = -35.02e3
venus.size = 0.95
    
mercury = Body('Mercury', 'darkmagenta')
mercury.mass = 0.3e24
mercury.p_x0 = 69.8e9
mercury.v_y0 = 47.7e3
mercury.size = 0.38
    
mars = Body('Mars', 'r')
mars.mass = 0.642e24
mars.p_x0 = 249.2e9
mars.v_y0 = 24.1e3
mars.size = 0.53
    
jupiter = Body('Jupiter', 'orangered')
jupiter.mass = 1.898e27
jupiter.p_x0 = 816.6e9
jupiter.v_y0 = 13.1e3
jupiter.size = 11.2
    
saturn = Body('Saturn', 'maroon')
saturn.mass = 5.68e26
saturn.p_x0 = 1514.5e9
saturn.v_y0 = 9.7e3
saturn.size = 9.45
    
uranus = Body('Uranus', 'darkgreen')
uranus.mass = 8.6e25
uranus.p_x0 = 3003.6e9
uranus.v_y0 = 6.8e3
uranus.size = 4
    
neptune = Body('Neptune', 'navy')
neptune.mass = 1.02e26
neptune.p_x0 = 4545.7e9
neptune.v_y0 = 5.4e3
neptune.size = 3.8
    
halley = Body('Halley', 'white')
halley.mass = 1.02e14
halley.p_x0 = 5248.2672e9
halley.v_y0 = 1e3

pluto = Body('Pluto', 'magenta')
pluto.mass = 0.0146e24
pluto.p_x0 = 737.9e9
pluto.v_y0 = 4.7e3

# %% [markdown]
# ---
# ### List with bodies object
#
# Separated in: Full solar system, Inner Solar System, Inner + Jupiter, Outter Solar System

# %%
bodies = [sun, mercury, venus, earth, mars, jupiter, saturn, uranus, neptune]
bodies_jp = [sun, earth, venus, mars, mercury, jupiter]
bodies_inner = [sun, earth, venus, mars, mercury]
bodies_outter = [sun, jupiter, saturn, uranus, neptune]

bodies_test = [sun, earth, mars]

# %% [markdown]
# ---
# ### Setting List with the timesteps and methods to simulate

# %%
60*60
# Out:
# 3600

# %%
hs = [3600*12]
m = ['leapfrog']
period = 800

# %% [markdown]
# ### Running Simulation #1

# %%
pos, vel, pot, ang_mo = sim.big_simulation(methods = m, t = period, steps = hs, bod = bodies)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-b0a5c03fe803> in <module>
# ----> 1 pos, vel, pot, ang_mo = sim.big_simulation(methods = m, t = period, steps = hs, bod = bodies)
#
# ~/repos/university-courses/comp-cientifica-II-2019-2/Project-II/local_functions.py in big_simulation(methods, steps, t, bod)
#     194         ang_mo[m] = []
#     195         for h in steps:
# --> 196             ret_pos, ret_vel, ret_energy, ret_ang = simulate(bod, period = t, method = m, step = h)
#     197             pos[m].append([h, ret_pos])
#     198             vel[m].append([h, ret_vel])
#
# ~/repos/university-courses/comp-cientifica-II-2019-2/Project-II/local_functions.py in simulate(bodies, step, period, method, G)
#      29                 if body is other:
#      30                     continue
# ---> 31                 acc_x, acc_y, body.potential, body.ang_mo = body.acceleration(bodies, pos = [body.p_x, body.p_y], retm = True, retpe = True)
#      32                 acc[body] = (acc_x, acc_y)
#      33
#
# ~/repos/university-courses/comp-cientifica-II-2019-2/Project-II/local_body.py in acceleration(self, bodies, pos, retpe, G, retm)
#      35             d_x = (other.p_x - pos[0])
#      36             d_y = (other.p_y - pos[1])
# ---> 37             d_z = (other.p_z - pos[2])
#      38             d = sqrt(d_x**2 + d_y**2 + d_z**2) ## Calculate the distance between the bodies
#      39             if d == 0:
#
# AttributeError: 'Body' object has no attribute 'p_z'

# %% [markdown]
# ### Plotting Inner Orbits

# %%
sim.big_plotter(methods = m, steps = hs, graph = ['orbit'], opt = [bodies_inner, 'The Inner Solar System'], pos_vec = pos)

# %% [markdown]
# ### Plotting Outer Orbits

# %%
sim.big_plotter(methods = m, steps = hs, graph = ['orbit'], opt = [bodies, 'The Inner Solar System'], pos_vec = pos)

# %%
end = time.time()

# %%
print("A simulação levou %f segundos" % (end - start))
# Out:
# A simulação levou 181.901056 segundos

# %%
24000/60
# Out:
# 400.0

# %%
sun = Body('Sun', 'black')
sun.mass = 1
sun.p_x0 = 1.38
sun.p_y0 = 0
sun.v_x0 = 0
sun.v_y0 = 0.584


planet = Body('Planet', 'purple')
planet.mass = 1
planet.p_x0 = 0
planet.p_y0 = 0.15
planet.v_x0 = 1.87
planet.v_y0 = 0.01

planet2 = Body('Planet 2', 'red')
planet2.mass = 1
planet2.p_x0 = -1.38
planet2.p_y0 = 0
planet2.v_x0 = 0
planet2.v_y0 = -0.584

planet2 = Body('Planet 3', 'red')
planet2.mass = 1
planet2.p_x0 = 0
planet2.p_y0 = -0.15
planet2.v_x0 = -1.87
planet2.v_y0 = 0

hs = [0.0025]
period = 30000

# %%
pos, vel, pot, ang_mo = sim.big_simulation(methods = ['leapfrog'], t = period, steps = hs, bod = [sun, planet, planet2])

# %%
pos, _, _, _ = sim.simulate([sun, planet, planet2], step = hs[0], period = period, method = 'leapfrog', G = 0.01)

# %%
sim.orbit_plotter(pos, [sun, planet, planet2], title = 'Coreografia 1', scale = False, color = False)

# %%
hs = [7200]
m = ['euler', 'leapfrog']
period = 10000
bodies = [sun, earth, venus, mars]

# %%
pos, vel, pot, ang_mo = sim.big_simulation(methods = m, t = period, steps = hs, bod = bodies)

# %%
sim.big_plotter(methods = m, steps = hs, graph = ['orbit'], opt = [bodies, 'The Inner Solar System'], pos_vec = pos)
